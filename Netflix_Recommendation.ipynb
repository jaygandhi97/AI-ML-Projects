# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=6ab413abb7440d75a616f6a60ac375a2e49fbcf21314c75fb6cdb65fd468d432
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
import os

# List files in the root directory of your Google Drive
root_dir = "/content/drive/My Drive/Colab Notebooks/Projects/NetFlix"
files = os.listdir(root_dir)
print(files)
# Out:
# ['Data MAster Sheet.xlsx', 'Data Preprocessing Template.ipynb', 'Covid Data.gsheet', 'Data Preprocessing Working Copy.ipynb', 'Untitled spreadsheet.gsheet', 'BigBasket.csv', 'NetFLix.csv', 'Netflix Recommendation.ipynb']

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
print(os.getcwd())
os.chdir("/content/drive/My Drive/Colab Notebooks/Projects/NetFlix")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/Projects/NetFlix
# /content/drive/My Drive/Colab Notebooks/Projects/NetFlix

# %%
dataset = pd.read_csv('BigBasket.csv' , header = None)
length = len(dataset)
transactions = []
for i in range(0, length):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
dataset.describe()
# Out:
#                    0              1              2              3          4   \
# count            7219           5529           4225           3226       2445
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              560            469            364            191        149
#
#                   5          6          7          8          9     10  \
# count           1800       1324        948        628        382   247
# unique           106        101         97         88         80    65
# top     french fries  green tea  green tea  green tea  green tea  curd
# freq             104         95         67         54         29    22
#
#                11         12         13                   14         15  \
# count         147         86         47                   25          8
# unique         48         43         28                   19          8
# ...

# %%
from apyori import apriori
basket_intelligence = apriori(transactions, min_support = 0.002, min_confidence = 0.2, min_lift = 3, min_length = 2)
results = list(basket_intelligence)
results

# %%
def inspect(results):

    product1 = [tuple(result[2][0][0])[0] for result in results]
    product2 = [tuple(result[2][0][1])[0]for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts =         [result[2][0][3] for result in results]
    return list(zip(product1, product2, supports, confidences, lifts))

Dataframe_intelligence = pd.DataFrame(inspect(results), columns=['product1', 'product2', 'support', 'confidence', 'lift'])
print(Dataframe_intelligence)
# Out:
#            product1          product2   support  confidence       lift
# 0            5 star          pancakes  0.002216    0.326531   3.446235
# 1          MTR Idli           parle g  0.002078    0.263158   3.247413
# 2           almonds           burgers  0.005402    0.265306   3.059497
# 3    barbecue sauce            turkey  0.002493    0.225000   3.585596
# 4              buns            paneer  0.016069    0.324022   3.285277
# ..              ...               ...       ...         ...        ...
# 487        tomatoes               nan  0.003048    0.333333   3.492501
# 488          paneer               nan  0.002216    0.355556   3.725335
# 489        tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 490          paneer     mineral water  0.002078    0.326087   9.019240
# 491            milk     mineral water  0.002078    0.258621   4.262518
#
# [492 rows x 5 columns]

# %%
jDataframe_intelligence.nlargest(n = 10, columns = 'lift')  #sorting with the highest lift
# Out:
#       product1          product2   support  confidence       lift
# 145      pasta      pepper spray  0.002493    0.461538  23.970116
# 373      pasta               nan  0.002493    0.461538  23.970116
# 391   tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 489   tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 420     paneer     mineral water  0.002078    0.326087   9.019240
# 490     paneer     mineral water  0.002078    0.326087   9.019240
# 328     paneer  vegetable basket  0.002493    0.219512   7.767934
# 461     paneer  vegetable basket  0.002493    0.219512   7.767934
# 220  olive oil              milk  0.002078    0.277778   7.653732
# 407  olive oil              milk  0.002078    0.277778   7.653732

# %%
print(os.getcwd())
os.chdir("/content/drive/My Drive/Colab Notebooks/Projects/NetFlix")
print(os.getcwd())
# Out:
# /content
# /content/drive/My Drive/Colab Notebooks/Projects/NetFlix

# %%
dataset = pd.read_csv('NetFLix.csv' , header = None)
length = len(dataset)
transactions = []
for i in range(0, length):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
from apyori import apriori
basket_intelligence = apriori(transactions, min_support = 0.002, min_confidence = 0.2, min_lift = 3, min_length = 2)
results = list(basket_intelligence)
results
# Out:
# [RelationRecord(items=frozenset({'3 Idiots', 'The Pianist'}), support=0.0021430484864720066, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3 Idiots'}), items_add=frozenset({'The Pianist'}), confidence=0.3076923076923077, lift=3.2264477095937774)]),
#  RelationRecord(items=frozenset({'The Good, the Bad and the Ugly', 'American History X'}), support=0.002009107956067506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'American History X'}), items_add=frozenset({'The Good, the Bad and the Ugly'}), confidence=0.2586206896551724, lift=3.2181034482758615)]),
#  RelationRecord(items=frozenset({'Black Panther', 'Captain America'}), support=0.00334851326011251, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Black Panther'}), confidence=0.24509803921568626, lift=5.140174047146949)]),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-f69480d79144> in <cell line: 1>()
# ----> 1 dataset = pd.read_csv('NetFlix.csv' , header = None)
#       2 length = len(dataset)
#       3 transactions = []
#       4 for i in range(0, length):
#       5     transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])
#
# ...

# %%
def inspect(results):

    product1 = [tuple(result[2][0][0])[0] for result in results]
    product2 = [tuple(result[2][0][1])[0]for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts =         [result[2][0][3] for result in results]
    return list(zip(product1, product2, supports, confidences, lifts))

Dataframe_intelligence = pd.DataFrame(inspect(results), columns=['product1', 'product2', 'support', 'confidence', 'lift'])
print(Dataframe_intelligence)
# Out:
#                      product1  \
# 0                    3 Idiots
# 1          American History X
# 2             Captain America
# 3             Game of thrones
# 4           Kanan Gill Comedy
# ..                        ...
# 500  The Shawshank Redemption
# 501  The Silence of the Lambs
# 502  The Silence of the Lambs
# 503           The Dark Knight
# 504           The Dark Knight
#
#                                               product2   support  confidence  \
# 0                                          The Pianist  0.002143    0.307692
# 1                       The Good, the Bad and the Ugly  0.002009    0.258621
# 2                                        Black Panther  0.003349    0.245098
# 3                             Comedy nights with Kapil  0.003215    0.205128
# 4                             Comedy nights with Kapil  0.008036    0.271493
# ..                                                 ...       ...         ...
# ...

# %%
Dataframe_intelligence.nlargest(n = 10, columns = 'lift')  #sorting with the highest lift
# Out:
#              product1                                           product2  \
# 89     Harry Potter 2                              crimes of grindelwald
# 295    Harry Potter 2                              crimes of grindelwald
# 184     The Lion King                                              Billa
# 409     The Lion King                                                nan
# 426   The Dark Knight                                          inception
# 504   The Dark Knight                                                nan
# 200  Schindler's List                                    The Dark Knight
# 418  Schindler's List                                    The Dark Knight
# 257     Prision Break  The Lord of the Rings: The Fellowship of the Ring
# 449     Prision Break  The Lord of the Rings: The Fellowship of the Ring
#
#       support  confidence       lift
# 89   0.002545    0.441860  23.069442
# 295  0.002545    0.441860  23.069442
# 184  0.002143    0.296296  10.584441
# ...

# %%
# !git config --global user.email "jaykgandhi@rediffmail.com"
# !git config --global user.name "jaygandhi97"

# %%
# !git clone https://github.com/jaygandhi97/AI-ML-Projects
# Out:
# Cloning into 'AI-ML-Projects'...
# ...

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a78b1fb2bab9> in <cell line: 1>()
# ----> 1 os.getcwd()
#
# NameError: name 'os' is not defined

# %%
# Out:
# /content/AI-ML-Projects
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-8d1790c2c711> in <cell line: 3>()
#       1 import os
#       2 print(os.getcwd())
# ----> 3 os.chdir("/content/drive/My Drive/Colab Notebooks/Projects/NetFlix")
#       4 print(os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Projects/NetFlix'
